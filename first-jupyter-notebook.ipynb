# %%
name = "John"

# %% [markdown]
# ## Sample heading
#
# *Note: this text will get itallicized*
#
# ## Another Headline (H2)
#
# This is normal paragraph. Now for some

# %%
name

# %%
name = "Corey"

# %%
# %lsmagic

# %%
# %pwd

# %%
# Simple demo of scatter plot. 

import numpy as np
import matplotlib.pyplot as plt

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 
# 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
# %%timeit
square_events = [n*n for n in range(1000)]
# Out:
# 22.7 µs ± 128 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.5.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 20.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.1 in ./bootcamp-venv/lib/python3.11/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.2-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.1/502.1 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in ./bootcamp-venv/lib/python3.11/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in ./bootcamp-venv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.5.3 pytz-2023.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,5))

# %%
df.head()
# Out:
#           0         1         2         3         4
# 0 -1.929236  0.287078  1.109638  0.301078 -1.119025
# 1  1.519258  0.233100  1.769758  0.122593 -0.868574
# 2  0.165279  1.520581 -1.337436 -1.093152 -0.645676
# 3 -0.433891  0.212182  0.311981  0.267375 -1.848620
# 4  1.312743 -0.650668  0.418370  1.588870 -1.561706
# 5 -1.060768  0.242606  0.945782 -0.489138 -0.751862
# 6  2.607231 -0.359729  0.201126  0.951192  1.030401
# 7 -1.379243 -0.791596  0.160998  0.272960 -0.805718
# 8  1.105544 -1.402805 -0.231230 -0.448573  2.085014
# 9  1.672026 -0.095211  0.899931 -0.619731  0.271670
