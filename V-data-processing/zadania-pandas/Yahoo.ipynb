# %%
import yahoo_fin.stock_info as yh

# %%
# !pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (0.8.9.1)
# Requirement already satisfied: requests-html in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: feedparser in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from yahoo_fin) (6.0.10)
# Requirement already satisfied: requests in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from yahoo_fin) (2.28.2)
# Requirement already satisfied: pandas in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from yahoo_fin) (1.5.3)
# Requirement already satisfied: sgmllib3k in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pandas->yahoo_fin) (2023.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pandas->yahoo_fin) (1.24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests->yahoo_fin) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests->yahoo_fin) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests->yahoo_fin) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests->yahoo_fin) (2022.12.7)
# Requirement already satisfied: pyquery in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests-html->yahoo_fin) (2.0.0)
# Requirement already satisfied: fake-useragent in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests-html->yahoo_fin) (1.1.3)
# Requirement already satisfied: parse in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: bs4 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: w3lib in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests-html->yahoo_fin) (2.1.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (6.1.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.65.0)
# Requirement already satisfied: websockets<11.0,>=10.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.4)
# Requirement already satisfied: six>=1.5 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from bs4->requests-html->yahoo_fin) (4.12.0)
# Requirement already satisfied: lxml>=2.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pyquery->requests-html->yahoo_fin) (4.9.2)
# Requirement already satisfied: cssselect>=1.2.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from pyquery->requests-html->yahoo_fin) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.15.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.4)

# %%
response = yh.get_day_gainers()
response
# Out:
#    Symbol                                           Name  Price (Intraday)  \
# 0     BUR                        Burford Capital Limited             11.06
# 1   KPELY                     Keppel Corporation Limited              8.45
# 2   SYRVF                                    Sacyr, S.A.              2.72
# 3      AI                                    C3.ai, Inc.             33.57
# 4    PACB        Pacific Biosciences of California, Inc.             11.58
# ..    ...                                            ...               ...
# 95   EXTR                         Extreme Networks, Inc.             19.12
# 96   APPN                             Appian Corporation             44.38
# 97  SHZHY  Shenzhou International Group Holdings Limited             10.34
# 98   DUOL                                 Duolingo, Inc.            142.59
# 99    NEP                    NextEra Energy Partners, LP             60.75
#
#     Change  % Change      Volume  Avg Vol (3 month)    Market Cap  \
# 0     3.84     53.19  16294000.0           657719.0  2.422000e+09
# 1     1.63     23.89     24137.0             3725.0  7.455000e+09
# 2     0.52     23.64     15857.0              255.0  2.058000e+09
# 3     5.94     21.50  61732000.0         19890000.0  3.767000e+09
# 4     1.82     18.65  11756000.0          4382000.0  2.861000e+09
# ..     ...       ...         ...                ...           ...
# 95    0.90      4.94   2214000.0          1405000.0  2.470000e+09
# 96    2.07      4.89    364864.0           389291.0  3.232000e+09
# 97    0.48      4.87     19228.0            32027.0  1.577900e+10
# 98    6.58      4.84    975067.0           596725.0  5.794000e+09
# 99    2.80      4.83   2841000.0           786232.0  5.401000e+09
#
#     PE Ratio (TTM)
# 0           276.50
# 1            12.07
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 95           49.03
# 96             NaN
# 97           30.41
# 98             NaN
# 99           10.31
#
# [100 rows x 9 columns]

# %%
msft_data = yh.get_data('msft')
msft_data['2023-03-':]
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "pandas/_libs/tslibs/parsing.pyx", line 440, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso
#   File "pandas/_libs/tslibs/parsing.pyx", line 649, in pandas._libs.tslibs.parsing.dateutil_parse
# ValueError: Unknown datetime string format, unable to parse: 2023-03-
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexes/datetimelike.py", line 310, in _maybe_cast_slice_bound
#     parsed, reso = self._parse_with_reso(label)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexes/datetimelike.py", line 230, in _parse_with_reso
#     parsed, reso_str = parsing.parse_time_string(label, freq)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "pandas/_libs/tslibs/parsing.pyx", line 367, in pandas._libs.tslibs.parsing.parse_time_string
#   File "pandas/_libs/tslibs/parsing.pyx", line 445, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso
# pandas._libs.tslibs.parsing.DateParseError: Unknown datetime string format, unable to parse: 2023-03-
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/ms/wkr5qnw531n49nj670qhvllh0000gn/T/ipykernel_9136/2067525955.py", line 2, in <module>
#     msft_data['2023-03-':]
#     ~~~~~~~~~^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/frame.py", line 3779, in __getitem__
#     indexer = convert_to_index_sliceable(self, key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexing.py", line 2494, in convert_to_index_sliceable
#     return idx._convert_slice_indexer(key, kind="getitem")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 4284, in _convert_slice_indexer
#     indexer = self.slice_indexer(start, stop, step)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexes/datetimes.py", line 809, in slice_indexer
#     return Index.slice_indexer(self, start, end, step, kind=kind)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 6559, in slice_indexer
#     start_slice, end_slice = self.slice_locs(start, end, step=step)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 6767, in slice_locs
#     start_slice = self.get_slice_bound(start, "left")
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 6676, in get_slice_bound
#     label = self._maybe_cast_slice_bound(label, side)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexes/datetimes.py", line 767, in _maybe_cast_slice_bound
#     label = super()._maybe_cast_slice_bound(label, side, kind=kind)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/pandas/core/indexes/datetimelike.py", line 315, in _maybe_cast_slice_bound
#     raise self._invalid_indexer("slice", label) from err
# TypeError: cannot do slice indexing on DatetimeIndex with these indexers [2023-03-] of type str
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1288, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1177, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1049, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 935, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mateusz/Documents/Code/data-science-bootcamp/bootcamp-venv/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1003, in get_records
#     lines, first = inspect.getsourcelines(etb.tb_frame)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py", line 1244, in getsourcelines
#     lines, lnum = findsource(object)
#                   ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py", line 1081, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code
