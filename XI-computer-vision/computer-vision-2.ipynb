# %%
import cv2
import matplotlib.pyplot as plt

# %%
def cv2_imshow(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.show()

# %%
original = cv2.imread('pexels-photo-6238297.jpeg')
cv2_imshow(original)

# %%
gray = cv2.cvtColor(table, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)

# %%
grey_reversed = (255-gray)
cv2_imshow(grey_reversed)

# %%
ret,thresh1 = cv2.threshold(grey_reversed,180,255,cv2.THRESH_BINARY)
cv2_imshow(thresh1)

# %%
thresh1[thresh1 != 0] = 255 # change everything to white where pixel is not black
cv2_imshow(thresh1)
