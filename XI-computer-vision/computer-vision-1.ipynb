# %%
pip install opencv-python
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
spongeboob = cv2.imread('data/SpongeBob_SquarePants_character.jpg', cv2.IMREAD_UNCHANGED)

# %%
def cv2_imshow(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.show()

# %%
cv2_imshow(spongeboob)

# %%
spongeboob.shape
# Out:
# (1200, 1200, 4)

# %%
spongeboob.mean()
# Out:
# 78.22065503472223

# %%
spongeboob.max()
# Out:
# 255

# %%
spongeboob.min()
# Out:
# 0

# %%
spongeboob.std()
# Out:
# 108.5685316228947

# %%
spongeboob_1_wymiar = spongeboob[:, :, -1]

# %%
spongeboob_1_wymiar.max()
# Out:
# 255

# %%
spongeboob_1_wymiar.min()
# Out:
# 0

# %%
spongeboob_1_wymiar.mean()
# Out:
# 112.17207708333333

# %%
glory_img_original = cv2.imread('ML-datasets/images/gory_lc.png')
glory_img_original = cv2.imread('data/IMG_1671.jpg')

# %%
glory_img_original.shape
# Out:
# (4032, 3024, 3)

# %%
cv2_imshow(glory_img_original)

# %%
glory_256_256 = cv2.resize(glory_img_original, (256, 256), interpolation = cv2.INTER_AREA)

# %%
cv2_imshow(glory_256_256)

# %%
glory_img_original.shape
# Out:
# (4032, 3024, 3)

# %%
scale_percent = 40
height = int(glory_img_original.shape[0] * scale_percent / 100 )
width = int(glory_img_original.shape[1] * scale_percent / 100 )
dim = (width, height)

glory_40_percent = cv2.resize(glory_img_original, dim, interpolation = cv2.INTER_AREA)

# %%
cv2_imshow(glory_40_percent)

# %%
scale_percent = 31
height = int(glory_img_original.shape[0] * scale_percent / 100 )
width = int(glory_img_original.shape[1] * scale_percent / 100 )
dim = (width, height)

glory_256_width = cv2.resize(glory_img_original, dim, interpolation = cv2.INTER_AREA)

# %%
cv2_imshow(glory_256_width)

# %%
cv2_imshow(glory_img_original)

# %% [markdown]
# Orginalny jest B G R

# %%
glory_img_original.shape
# Out:
# (4032, 3024, 3)

# %%
B = glory_img_original[:,:,0]
G = glory_img_original[:,:,1]
R = glory_img_original[:,:,2]

cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)

# %%
gray_glory =  cv2.cvtColor(glory_img_original, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_glory)

# %%
RGB =  cv2.cvtColor(glory_img_original, cv2.COLOR_BGR2RGB)
cv2_imshow(RGB)

# %%
HSV =  cv2.cvtColor(glory_img_original, cv2.COLOR_BGR2HSV)
cv2_imshow(HSV)

# %%
green = glory_img_original.copy()
green[:, :, 0] = 0
green[:, :, 2] = 0
cv2_imshow(green)
