# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import ipywidgets as widgets
import pandas as pd
import numpy as np

from IPython.display import Math, clear_output

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (8.0.6)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipywidgets) (3.0.7)
# Requirement already satisfied: ipython>=6.1.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipywidgets) (8.12.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipywidgets) (4.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipywidgets) (6.22.0)
# Requirement already satisfied: psutil in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.4)
# Requirement already satisfied: nest-asyncio in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.0)
# Requirement already satisfied: tornado>=6.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: appnope in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: pyzmq>=20 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.0.2)
# Requirement already satisfied: packaging in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.1.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: backcall in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.0)
# Requirement already satisfied: jedi>=0.16 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: decorator in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: stack-data in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
def linear_function(theta, x):
    return theta[0] + theta[1] * x

def plot_function(theta, X, color):
    X_new = [min(X) - 1, max(X) + 1]
    y_new = [linear_function(theta, x) for x in X_new]
    plt.plot(X_new, y_new, linewidth=2, color=color)

def plot_points(X, y):
    plt.figure(figsize=(20, 10))
    plt.scatter(X, y, s=200)
    plt.xlabel("Liczba pożarów")
    plt.ylabel("Liczba włamań")

# %% [markdown]
# ## Zadanie 1

# %%
df = pd.read_csv("data/fires_thefts (1).csv")

# %%
df.head()
# Out:
#    fires  thefts
# 0    6.2      29
# 1    9.5      44
# 2   10.5      36
# 3    7.7      37
# 4    8.6      53

# %%
X = df[['fires']]
y = df['thefts']
model = LinearRegression()

model.fit(X, y)

print("model.coef_: ",model.coef_)
print("model.intercept_ :",model.intercept_)

model.predict([[33]])
# Out:
# model.coef_:  [1.313456]
# model.intercept_ : 16.99515723273956
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([60.3392054])

# %%
model = LinearRegression()

# %%
model.fit(X, y)

print("model.coef_: ",model.coef_)
print("model.intercept_ :",model.intercept_)
# Out:
# model.coef_:  [1.313456]
# model.intercept_ : 16.99515723273956

# %%
model.predict([[33]])
# Out:
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([60.3392054])

# %% [markdown]
# ## Zadanie 2

# %%
def linear_function(theta, x):
    return theta[0] + theta[1] * x

def plot_function(theta, X, color):
    X_new = [min(X) - 1, max(X) + 1]
    y_new = [linear_function(theta, x) for x in X_new]
    plt.plot(X_new, y_new, linewidth=2, color=color)

def plot_points(X, y):
    plt.figure(figsize=(20, 10))
    plt.scatter(X, y, s=200)
    plt.xlabel("Liczba pożarów")
    plt.ylabel("Liczba włamań")

# %%
#h - linear_function
def J(h, theta, X, y):
    # h to funkcja
    # theta to lista współczynników: [theta_0, theta_1]
    # X i y to zmienne przechowujące dane
    # wywołanie tej funkcji w sposób J(linear_function, [1, 2], X, y) powinno zwrócić wartość 228.41857142857137
    m = y.size
    return 1/(2*m)*sum((h(theta,X[i][0])-y[i])**2 for i in range(m))

# %%
def J(h, theta, X, y):
  if h == 'linear_function':
    m = len(X)
    X = np.column_stack((np.ones(m), X))
    return np.sum((np.dot(X, theta) - y) ** 2) / (2 * m)

# %%
J(linear_function,[1,2],X,y)

# %%
J(linear_function,[200,0.1],X,y)

# %% [markdown]
# ### Zadanie 4

# %%
slider_theta_0 = widgets.FloatSlider(min=-20, max=20, step=0.1, value=, description=r'theta0', layout={'width': "auto"})
slider_theta_1 = widgets.FloatSlider(min=-20, max=20, step=0.1, value=, description=r'theta1', layout={'width': "auto"})
out = widgets.Output()
button = widgets.Button(width=100, description="Show")

def btn_event_handler(event):
    with out:
        clear_output(wait=True)
        plot_points(X, y)
        plot_function([slider_theta_0.value, slider_theta_1.value], X, 'r')
        plt.show()
        display(Math(rf"\Large J(\theta) = {J(linear_function, [slider_theta_0.value, slider_theta_1.value], X, y):.4f}"))
        
        
with out:
    plot_points(X, y)
    plt.show()

button.on_click(btn_event_handler)
display(widgets.VBox([slider_theta_0, slider_theta_1, button]))
display(out)
# Out:
# VBox(children=(FloatSlider(value=20.0, description='theta0', layout=Layout(width='auto'), max=20.0, min=-20.0)…
# Output()

# %% [markdown]
# ### Zadanie 4

# %%
X = df[['fires']]
y = df['thefts']
model = LinearRegression()

model.fit(X, y)

print("model.intercept_ :",model.intercept_)
print("model.coef_ :",model.coef_)

model.predict([[33]])
# Out:
# model.intercept_ : 16.99515723273956
# model.coef_ : [1.313456]
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([60.3392054])

# %% [markdown]
# ### Zadanie 5
#
# Wytrenuj na tych danych model regresji liniowej

# %%
X = df[['fires']]
y = df['thefts']
model = LinearRegression()

model.fit(X, y)

print("model.intercept_ :",model.intercept_)
print("model.coef_ :",model.coef_)

model.predict([[1000]])
# Out:
# model.intercept_ : 16.99515723273956
# model.coef_ : [1.313456]
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1330.45116216])

# %% [markdown]
# ### Zadanie 6
#
# Korzystając z zaimplementowanych wyżej funkcji oraz współczynników wytrenowanego modelu nanieś na wykres prostę regresyjną i oblicz wartość funkcji kosztu dla tych współczynników. Spójrz, jak daleko byłeś od idealnego rozwiązania dobierając parametry ręcznie.

# %%
import matplotlib.pyplot as plt

# X - wektor zmiennych niezależnych
# y - wektor zmiennych zależnych
# y_pred - wektor wartości przewidywanych przez model
plt.scatter(X, y)
plt.plot(X, model.predict(X), color='red')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X, y)
# y - wektor zmiennych zależnych
# y_pred - wektor wartości przewidywanych przez model
mse = mean_squared_error(y , model.predict(X))
mse
# Out:
# 360.8201564131022

# %% [markdown]
# ### Zadanie 7
#
# Wykorzystując uzyskany model regresyjny przepowiedz liczbę włamań na tysiąc mieszkańców dla dzielnic, w których występują średnio kolejno: 10, 20 i 50 pożarów na tysiąc gospodarstw domowych.

# %%
print(model.predict([[10]]))
print(model.predict([[20]]))
print(model.predict([[50]]))
# Out:
# [30.12971728]
# [43.26427733]
# [82.66795748]
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Zadanie 8
#
# Wytrenuj model regresyjny drzewa decyzyjnego i dokonaj predykcji dla tych samych wartości pożarów na tysiąc gospodarstw domowych co wyżej. Porównaj otrzymane wyniki.

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()

# %%
X = X.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 X = X.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
model.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %%
print(model.predict([[10]]))
print(model.predict([[20]]))
print(model.predict([[50]]))
# Out:
# [38.875]
# [27.22222222]
# [63.4]
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
model = DecisionTreeRegressor(
        max_depth=5,
        min_samples_leaf=5)

model.fit(X, y)

from sklearn import tree
fig = plt.figure(figsize=(20,15))
tree_plot = tree.plot_tree(model,feature_names=X.columns,filled=True)

# %%
print(model.predict([[10]]))
print(model.predict([[20]]))
print(model.predict([[50]]))
# Out:
# [38.875]
# [27.22222222]
# [63.4]
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# /Users/mateusz/Documents/Code/data-science-bootcamp/final-venv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
